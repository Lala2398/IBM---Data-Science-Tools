# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Lala Ibadullayeva**

# %% [markdown]
# Anthropologist, PhD candidate of Molecular Biology and Learning Data Science

# %% [markdown]
# _I am interested in data science because, I like the fact that the sciences combine interestingly with each other and make multidisciplinary innovations._

# %% [markdown]
# ### On the code line should print 'Hello World!'

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# https://en.wikipedia.org/wiki/Fuzzy_logic
#
# * one
# * two
# * three
#
# ![Fig-y_Part_of_ML_as_subfield_of_AI_or_AI_as_subfield_of_ML.jpg](attachment:Fig-y_Part_of_ML_as_subfield_of_AI_or_AI_as_subfield_of_ML.jpg)
